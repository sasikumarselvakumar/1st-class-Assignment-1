# %% [markdown]
# <a href="https://colab.research.google.com/github/sasikumarselvakumar/1st-class-Assignment-1/blob/main/1st_class_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Simple Banking System

username = "admin"
password = "1234"
balance = 1000

u = input("Enter Username: ")
p = input("Enter Password: ")

if u == username and p == password:
    print("Login Successful")

    while True:
        print("\n1.Deposit  2.Withdraw  3.Check Balance  4.Exit")
        choice = input("Choose option: ")

        if choice == "1":
            amount = float(input("Enter amount to deposit: "))
            balance += amount
            print("Amount Deposited")

        elif choice == "2":
            amount = float(input("Enter amount to withdraw: "))
            if amount <= balance:
                balance -= amount
                print("Amount Withdrawn")
            else:
                print("Insufficient Balance")

        elif choice == "3":
            print("Current Balance:", balance)

        elif choice == "4":
            print("Thank You")
            break

        else:
            print("Invalid Option")

else:
    print("Wrong Username or Password")
# Out:
# Login Successful
#
# 1.Deposit  2.Withdraw  3.Check Balance  4.Exit
# Amount Deposited
#
# 1.Deposit  2.Withdraw  3.Check Balance  4.Exit
# Current Balance: 2000.0
#
# 1.Deposit  2.Withdraw  3.Check Balance  4.Exit
